# %% [markdown]
# Remarks:
# - Be carefull to not exceed request limits (20 per second, 100 per 2 min) otherwise your request will return error code and must be managed properly (basically waiting)
#     - When debuging use a "guard" variable in you loop to unsure you don't explode the request quota
# - only use standard libraries, the goal is to learns basic of api request/pandas formating

# %% [markdown]
# Ressources:
# - api portal: https://developer.riotgames.com/
# - getting started: https://developer.riotgames.com/docs/portal#_getting-started
# - docs: https://developer.riotgames.com/docs/lol
# - matchid list: https://canisback.com/matchId/
# - riot api libraries: https://riot-api-libraries.readthedocs.io/en/latest/collectingdata.html

# %% [markdown]
# - Register on to get a personal api key
# - Register a product to activate the key
#     - Just put the title of the project and describe that its for educational purpose

# %% [markdown]
# # Settings

# %% [markdown]
# ## User Variables

# %%
RIOT_API_KEY = "RGAPI-a57dffb3-24ca-46e2-8f52-c6eaa85b3b6e"

PATCH = "12.19.1"

CHAMPIONS_JSON_URL = "https://ddragon.leagueoflegends.com/cdn/" + PATCH + "/data/en_US/champion.json"

PLAYER_NAME = "sasukaru"
print(CHAMPIONS_JSON_URL)
# Out:
# https://ddragon.leagueoflegends.com/cdn/12.19.1/data/en_US/champion.json

# %% [markdown]
# ## Dev variables

# %% [markdown]
# # 1. imports

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# # 1. REST basics request and dataframe conversion

# %% [markdown]
# ## 1.1 Extract and convert the list of champions (json file) into a pandas dataframe

# %%
from urllib.request import urlopen
data=json.loads(urlopen(CHAMPIONS_JSON_URL).read())
champions = data['data'].keys()
# Out:
# dict_keys(['Aatrox', 'Ahri', 'Akali', 'Akshan', 'Alistar', 'Amumu', 'Anivia', 'Annie', 'Aphelios', 'Ashe', 'AurelionSol', 'Azir', 'Bard', 'Belveth', 'Blitzcrank', 'Brand', 'Braum', 'Caitlyn', 'Camille', 'Cassiopeia', 'Chogath', 'Corki', 'Darius', 'Diana', 'Draven', 'DrMundo', 'Ekko', 'Elise', 'Evelynn', 'Ezreal', 'Fiddlesticks', 'Fiora', 'Fizz', 'Galio', 'Gangplank', 'Garen', 'Gnar', 'Gragas', 'Graves', 'Gwen', 'Hecarim', 'Heimerdinger', 'Illaoi', 'Irelia', 'Ivern', 'Janna', 'JarvanIV', 'Jax', 'Jayce', 'Jhin', 'Jinx', 'Kaisa', 'Kalista', 'Karma', 'Karthus', 'Kassadin', 'Katarina', 'Kayle', 'Kayn', 'Kennen', 'Khazix', 'Kindred', 'Kled', 'KogMaw', 'Leblanc', 'LeeSin', 'Leona', 'Lillia', 'Lissandra', 'Lucian', 'Lulu', 'Lux', 'Malphite', 'Malzahar', 'Maokai', 'MasterYi', 'MissFortune', 'MonkeyKing', 'Mordekaiser', 'Morgana', 'Nami', 'Nasus', 'Nautilus', 'Neeko', 'Nidalee', 'Nilah', 'Nocturne', 'Nunu', 'Olaf', 'Orianna', 'Ornn', 'Pantheon', 'Poppy', 'Pyke', 'Qiyana', 'Quinn', 'Rakan', 'Rammus', 'RekSai', 'Rell', 'Renata', 'Renekton', 'Rengar', 'Riven', 'Rumble', 'Ryze', 'Samira', 'Sejuani', 'Senna', 'Seraphine', 'Sett', 'Shaco', 'Shen', 'Shyvana', 'Singed', 'Sion', 'Sivir', 'Skarner', 'Sona', 'Soraka', 'Swain', 'Sylas', 'Syndra', 'TahmKench', 'Taliyah', 'Talon', 'Taric', 'Teemo', 'Thresh', 'Tristana', 'Trundle', 'Tryndamere', 'TwistedFate', 'Twitch', 'Udyr', 'Urgot', 'Varus', 'Vayne', 'Veigar', 'Velkoz', 'Vex', 'Vi', 'Viego', 'Viktor', 'Vladimir', 'Volibear', 'Warwick', 'Xayah', 'Xerath', 'XinZhao', 'Yasuo', 'Yone', 'Yorick', 'Yuumi', 'Zac', 'Zed', 'Zeri', 'Ziggs', 'Zilean', 'Zoe', 'Zyra'])

# %%
df=pd.DataFrame(data['data']).transpose()
df
# Out:
#          version       id  key     name                   title  \
# Aatrox   12.19.1   Aatrox  266   Aatrox        the Darkin Blade
# Ahri     12.19.1     Ahri  103     Ahri     the Nine-Tailed Fox
# Akali    12.19.1    Akali   84    Akali      the Rogue Assassin
# Akshan   12.19.1   Akshan  166   Akshan      the Rogue Sentinel
# Alistar  12.19.1  Alistar   12  Alistar            the Minotaur
# ...          ...      ...  ...      ...                     ...
# Zeri     12.19.1     Zeri  221     Zeri       The Spark of Zaun
# Ziggs    12.19.1    Ziggs  115    Ziggs  the Hexplosives Expert
# Zilean   12.19.1   Zilean   26   Zilean        the Chronokeeper
# Zoe      12.19.1      Zoe  142      Zoe  the Aspect of Twilight
# Zyra     12.19.1     Zyra  143     Zyra      Rise of the Thorns
#
#                                                      blurb  \
# Aatrox   Once honored defenders of Shurima against the ...
# Ahri     Innately connected to the latent power of Rune...
# Akali    Abandoning the Kinkou Order and her title of t...
# Akshan   Raising an eyebrow in the face of danger, Aksh...
# Alistar  Always a mighty warrior with a fearsome reputa...
# ...                                                    ...
# Zeri     A headstrong, spirited young woman from Zaun's...
# Ziggs    With a love of big bombs and short fuses, the ...
# Zilean   Once a powerful Icathian mage, Zilean became o...
# Zoe      As the embodiment of mischief, imagination, an...
# Zyra     Born in an ancient, sorcerous catastrophe, Zyr...
#
#                                                       info  \
# Aatrox   {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# Ahri     {'attack': 3, 'defense': 4, 'magic': 8, 'diffi...
# Akali    {'attack': 5, 'defense': 3, 'magic': 8, 'diffi...
# Akshan   {'attack': 0, 'defense': 0, 'magic': 0, 'diffi...
# Alistar  {'attack': 6, 'defense': 9, 'magic': 5, 'diffi...
# ...                                                    ...
# Zeri     {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# Ziggs    {'attack': 2, 'defense': 4, 'magic': 9, 'diffi...
# Zilean   {'attack': 2, 'defense': 5, 'magic': 8, 'diffi...
# Zoe      {'attack': 1, 'defense': 7, 'magic': 8, 'diffi...
# Zyra     {'attack': 4, 'defense': 3, 'magic': 8, 'diffi...
#
#                                                      image  \
# Aatrox   {'full': 'Aatrox.png', 'sprite': 'champion0.pn...
# Ahri     {'full': 'Ahri.png', 'sprite': 'champion0.png'...
# Akali    {'full': 'Akali.png', 'sprite': 'champion0.png...
# Akshan   {'full': 'Akshan.png', 'sprite': 'champion0.pn...
# Alistar  {'full': 'Alistar.png', 'sprite': 'champion0.p...
# ...                                                    ...
# Zeri     {'full': 'Zeri.png', 'sprite': 'champion5.png'...
# Ziggs    {'full': 'Ziggs.png', 'sprite': 'champion5.png...
# Zilean   {'full': 'Zilean.png', 'sprite': 'champion5.pn...
# Zoe      {'full': 'Zoe.png', 'sprite': 'champion5.png',...
# Zyra     {'full': 'Zyra.png', 'sprite': 'champion5.png'...
#
#                          tags     partype  \
# Aatrox        [Fighter, Tank]  Blood Well
# Ahri         [Mage, Assassin]        Mana
# Akali              [Assassin]      Energy
# Akshan   [Marksman, Assassin]        Mana
# Alistar       [Tank, Support]        Mana
# ...                       ...         ...
# Zeri               [Marksman]        Mana
# Ziggs                  [Mage]        Mana
# Zilean        [Support, Mage]        Mana
# Zoe           [Mage, Support]        Mana
# Zyra          [Mage, Support]        Mana
#
#                                                      stats
# Aatrox   {'hp': 650, 'hpperlevel': 114, 'mp': 0, 'mpper...
# Ahri     {'hp': 570, 'hpperlevel': 96, 'mp': 418, 'mppe...
# Akali    {'hp': 570, 'hpperlevel': 119, 'mp': 200, 'mpp...
# Akshan   {'hp': 630, 'hpperlevel': 104, 'mp': 350, 'mpp...
# Alistar  {'hp': 670, 'hpperlevel': 120, 'mp': 350, 'mpp...
# ...                                                    ...
# Zeri     {'hp': 600, 'hpperlevel': 109, 'mp': 250, 'mpp...
# Ziggs    {'hp': 606, 'hpperlevel': 106, 'mp': 480, 'mpp...
# Zilean   {'hp': 574, 'hpperlevel': 96, 'mp': 452, 'mppe...
# Zoe      {'hp': 630, 'hpperlevel': 106, 'mp': 425, 'mpp...
# Zyra     {'hp': 574, 'hpperlevel': 93, 'mp': 418, 'mppe...
#
# [161 rows x 11 columns]

# %% [markdown]
# ## 1.2 Create a new dataframe with only the rows of champions whose key is 266, 115 and 142

# %%
df[df["key"].isin(["266","115","142"])]
# Out:
#         version      id  key    name                   title  \
# Aatrox  12.19.1  Aatrox  266  Aatrox        the Darkin Blade
# Ziggs   12.19.1   Ziggs  115   Ziggs  the Hexplosives Expert
# Zoe     12.19.1     Zoe  142     Zoe  the Aspect of Twilight
#
#                                                     blurb  \
# Aatrox  Once honored defenders of Shurima against the ...
# Ziggs   With a love of big bombs and short fuses, the ...
# Zoe     As the embodiment of mischief, imagination, an...
#
#                                                      info  \
# Aatrox  {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# Ziggs   {'attack': 2, 'defense': 4, 'magic': 9, 'diffi...
# Zoe     {'attack': 1, 'defense': 7, 'magic': 8, 'diffi...
#
#                                                     image             tags  \
# Aatrox  {'full': 'Aatrox.png', 'sprite': 'champion0.pn...  [Fighter, Tank]
# Ziggs   {'full': 'Ziggs.png', 'sprite': 'champion5.png...           [Mage]
# Zoe     {'full': 'Zoe.png', 'sprite': 'champion5.png',...  [Mage, Support]
#
#            partype                                              stats
# Aatrox  Blood Well  {'hp': 650, 'hpperlevel': 114, 'mp': 0, 'mpper...
# Ziggs         Mana  {'hp': 606, 'hpperlevel': 106, 'mp': 480, 'mpp...
# Zoe           Mana  {'hp': 630, 'hpperlevel': 106, 'mp': 425, 'mpp...

# %% [markdown]
# ## 1.3 Create a dataframe containing only the champions of the current free rotation

# %%
api_url =f"https://euw1.api.riotgames.com/lol/platform/v3/champion-rotations?api_key={RIOT_API_KEY}"
response = requests.get(api_url)
free_rotation = response.json()['freeChampionIds']
free_rotation
# Out:
# [2, 8, 10, 19, 33, 50, 55, 62, 78, 104, 106, 120, 147, 164, 427, 876]

# %%
df[df["key"].isin(map(str,free_rotation))]
# Out:
#             version          id  key       name                       title  \
# Camille     12.19.1     Camille  164    Camille            the Steel Shadow
# Graves      12.19.1      Graves  104     Graves                  the Outlaw
# Hecarim     12.19.1     Hecarim  120    Hecarim           the Shadow of War
# Ivern       12.19.1       Ivern  427      Ivern            the Green Father
# Katarina    12.19.1    Katarina   55   Katarina          the Sinister Blade
# Kayle       12.19.1       Kayle   10      Kayle               the Righteous
# Lillia      12.19.1      Lillia  876     Lillia           the Bashful Bloom
# MonkeyKing  12.19.1  MonkeyKing   62     Wukong             the Monkey King
# Olaf        12.19.1        Olaf    2       Olaf               the Berserker
# Poppy       12.19.1       Poppy   78      Poppy        Keeper of the Hammer
# Rammus      12.19.1      Rammus   33     Rammus              the Armordillo
# Seraphine   12.19.1   Seraphine  147  Seraphine  the Starry-Eyed Songstress
# Swain       12.19.1       Swain   50      Swain    the Noxian Grand General
# Vladimir    12.19.1    Vladimir    8   Vladimir          the Crimson Reaper
# Volibear    12.19.1    Volibear  106   Volibear        the Relentless Storm
# Warwick     12.19.1     Warwick   19    Warwick   the Uncaged Wrath of Zaun
#
#                                                         blurb  \
# Camille     Weaponized to operate outside the boundaries o...
# Graves      Malcolm Graves is a renowned mercenary, gamble...
# Hecarim     Hecarim is a spectral fusion of man and beast,...
# Ivern       Ivern Bramblefoot, known to many as the Green ...
# Katarina    Decisive in judgment and lethal in combat, Kat...
# Kayle       Born to a Targonian Aspect at the height of th...
# Lillia      Intensely shy, the fae fawn Lillia skittishly ...
# MonkeyKing  Wukong is a vastayan trickster who uses his st...
# Olaf        An unstoppable force of destruction, the axe-w...
# Poppy       Runeterra has no shortage of valiant champions...
# Rammus      Idolized by many, dismissed by some, mystifyin...
# Seraphine   Born in Piltover to Zaunite parents, Seraphine...
# Swain       Jericho Swain is the visionary ruler of Noxus,...
# Vladimir    A fiend with a thirst for mortal blood, Vladim...
# Volibear    To those who still revere him, the Volibear is...
# Warwick     Warwick is a monster who hunts the gray alleys...
#
#                                                          info  \
# Camille     {'attack': 8, 'defense': 6, 'magic': 3, 'diffi...
# Graves      {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# Hecarim     {'attack': 8, 'defense': 6, 'magic': 4, 'diffi...
# Ivern       {'attack': 3, 'defense': 5, 'magic': 7, 'diffi...
# Katarina    {'attack': 4, 'defense': 3, 'magic': 9, 'diffi...
# Kayle       {'attack': 6, 'defense': 6, 'magic': 7, 'diffi...
# Lillia      {'attack': 0, 'defense': 2, 'magic': 10, 'diff...
# MonkeyKing  {'attack': 8, 'defense': 5, 'magic': 2, 'diffi...
# Olaf        {'attack': 9, 'defense': 5, 'magic': 3, 'diffi...
# Poppy       {'attack': 6, 'defense': 7, 'magic': 2, 'diffi...
# Rammus      {'attack': 4, 'defense': 10, 'magic': 5, 'diff...
# Seraphine   {'attack': 0, 'defense': 0, 'magic': 0, 'diffi...
# Swain       {'attack': 2, 'defense': 6, 'magic': 9, 'diffi...
# Vladimir    {'attack': 2, 'defense': 6, 'magic': 8, 'diffi...
# Volibear    {'attack': 7, 'defense': 7, 'magic': 4, 'diffi...
# Warwick     {'attack': 9, 'defense': 5, 'magic': 3, 'diffi...
#
#                                                         image  \
# Camille     {'full': 'Camille.png', 'sprite': 'champion0.p...
# Graves      {'full': 'Graves.png', 'sprite': 'champion1.pn...
# Hecarim     {'full': 'Hecarim.png', 'sprite': 'champion1.p...
# Ivern       {'full': 'Ivern.png', 'sprite': 'champion1.png...
# Katarina    {'full': 'Katarina.png', 'sprite': 'champion1....
# Kayle       {'full': 'Kayle.png', 'sprite': 'champion1.png...
# Lillia      {'full': 'Lillia.png', 'sprite': 'champion2.pn...
# MonkeyKing  {'full': 'MonkeyKing.png', 'sprite': 'champion...
# Olaf        {'full': 'Olaf.png', 'sprite': 'champion2.png'...
# Poppy       {'full': 'Poppy.png', 'sprite': 'champion3.png...
# Rammus      {'full': 'Rammus.png', 'sprite': 'champion3.pn...
# Seraphine   {'full': 'Seraphine.png', 'sprite': 'champion3...
# Swain       {'full': 'Swain.png', 'sprite': 'champion4.png...
# Vladimir    {'full': 'Vladimir.png', 'sprite': 'champion4....
# Volibear    {'full': 'Volibear.png', 'sprite': 'champion4....
# Warwick     {'full': 'Warwick.png', 'sprite': 'champion4.p...
#
#                           tags       partype  \
# Camille        [Fighter, Tank]          Mana
# Graves              [Marksman]          Mana
# Hecarim        [Fighter, Tank]          Mana
# Ivern          [Support, Mage]          Mana
# Katarina      [Assassin, Mage]          None
# Kayle       [Fighter, Support]          Mana
# Lillia         [Fighter, Mage]          Mana
# MonkeyKing     [Fighter, Tank]          Mana
# Olaf           [Fighter, Tank]          Mana
# Poppy          [Tank, Fighter]          Mana
# Rammus         [Tank, Fighter]          Mana
# Seraphine      [Mage, Support]          Mana
# Swain          [Mage, Fighter]          Mana
# Vladimir                [Mage]  Crimson Rush
# Volibear       [Fighter, Tank]          Mana
# Warwick        [Fighter, Tank]          Mana
#
#                                                         stats
# Camille     {'hp': 646, 'hpperlevel': 99, 'mp': 339, 'mppe...
# Graves      {'hp': 625, 'hpperlevel': 106, 'mp': 325, 'mpp...
# Hecarim     {'hp': 625, 'hpperlevel': 99, 'mp': 277, 'mppe...
# Ivern       {'hp': 655, 'hpperlevel': 99, 'mp': 450, 'mppe...
# Katarina    {'hp': 672, 'hpperlevel': 108, 'mp': 0, 'mpper...
# Kayle       {'hp': 670, 'hpperlevel': 92, 'mp': 330, 'mppe...
# Lillia      {'hp': 625, 'hpperlevel': 104, 'mp': 410, 'mpp...
# MonkeyKing  {'hp': 610, 'hpperlevel': 99, 'mp': 300, 'mppe...
# Olaf        {'hp': 645, 'hpperlevel': 119, 'mp': 316, 'mpp...
# Poppy       {'hp': 610, 'hpperlevel': 104, 'mp': 280, 'mpp...
# Rammus      {'hp': 634, 'hpperlevel': 94, 'mp': 310, 'mppe...
# Seraphine   {'hp': 570, 'hpperlevel': 104, 'mp': 440, 'mpp...
# Swain       {'hp': 595, 'hpperlevel': 99, 'mp': 468, 'mppe...
# Vladimir    {'hp': 607, 'hpperlevel': 110, 'mp': 2, 'mpper...
# Volibear    {'hp': 650, 'hpperlevel': 104, 'mp': 350, 'mpp...
# Warwick     {'hp': 620, 'hpperlevel': 99, 'mp': 280, 'mppe...

# %% [markdown]
# # 2. Combining multiple api entry points and formating data

# %% [markdown]
# ## 2.1 Extract the puuid of a player

# %%
recup_puuid = f"https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/{PLAYER_NAME}?api_key={RIOT_API_KEY}"
reponse_puuid = requests.get(recup_puuid)
res_puuid = reponse_puuid.json()
puuid = res_puuid["puuid"]
puuid
# Out:
# 'QEbFAox6b90ARcUXKddMIBKZFw3OQTEGKuvapgRjrF9jytBmLHGVp5AnDLovKUrFDbFwtD-ZCg1brA'

# %%
res_puuid
# Out:
# {'id': 'd3Y_qDS2_y5Fak5AtnvhNzail1Gqv1JPsSG0Sosl-D6Wtyk',
#  'accountId': 'H8q3bfAHTKnR-ecDjyilTFgxIQxP3Dd7bNT8i0_9UpTdtg',
#  'puuid': 'QEbFAox6b90ARcUXKddMIBKZFw3OQTEGKuvapgRjrF9jytBmLHGVp5AnDLovKUrFDbFwtD-ZCg1brA',
#  'name': 'sasukaru',
#  'profileIconId': 547,
#  'revisionDate': 1665263068000,
#  'summonerLevel': 182}

# %% [markdown]
# ## 2.2 Extract the 10 last matches of the player

# %%
nb_games=10
recup_games = f"https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count={nb_games}&api_key={RIOT_API_KEY}"
reponse_games = requests.get(recup_games)
res_games = reponse_games.json()
res_games
# Out:
# ['EUW1_6099023320',
#  'EUW1_6098938001',
#  'EUW1_6098923859',
#  'EUW1_6095728706',
#  'EUW1_6095586878',
#  'EUW1_6095573397',
#  'EUW1_6094521483',
#  'EUW1_6093028177',
#  'EUW1_6086735640',
#  'EUW1_6086743125']

# %% [markdown]
# ## 2.3 Extract some basic infos of each match into a dataframe row

# %%
api_url = f"https://europe.api.riotgames.com/lol/match/v5/matches/{res_games[0]}?api_key={RIOT_API_KEY}"
response = requests.get(api_url)
match = response.json()
match
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'EUW1_6099023320',
#   'participants': ['I9zqZeIvTdKGdnmleOmmgbnohX5gfvaHYSb85EMxPZRqyVqaJgyHZ1mr5phJk6QP7JbdDpIhHkiqWw',
#    'aYebJByywsg9lCWUE5Q9rwxjGX63bP9OOfTVzB6smKFMEMc0Fb7t9-WEc2GdnOSKZfOj8gZOaHGmbg',
#    'jFsWEnsLlBlqnTL5nwrwSGYN16sfwtjP8uY2hAud5Ig9qFx-4ud61YrRF1BGzrBkTgYUuQdFoNLRtw',
#    'l9cVfu51JMHqDepa5v-FiNJNK6bI3aXhaTumk6w0JJ0d2MTbjWG7UKi-G8rN3Ar4DJIbZj3_z0FWrg',
#    '31o81vZvFSySno1vJzz3c1-VrAwUmzVN840r6-Vz2RfEkoLBJJTnMs5kvWP-72eVVtmvSsAqoUZEig',
#    'QEbFAox6b90ARcUXKddMIBKZFw3OQTEGKuvapgRjrF9jytBmLHGVp5AnDLovKUrFDbFwtD-ZCg1brA',
#    '09_uFTBU2y5MYUmwhIb5zB2wsnBFgE718IJsvdW1CZUVrrCVa0ptjlh_QGKvw5BKLRN81dCajs76Gg',
#    'CKFcnB6V1j_hrylsFGcU8uQTXgJ11z3RmP8F9Omt-M0Atb8fC_WowRhnaR7ss7akfPn2GFATn0Fnhg',
#    '_fg-80eVskvALqfFDEgwI95q_HkF_Yvkxykmf9BNMAZrFv4hYhXnxrQDTgRDR-yz_ZnBK0Tl8wvOSw',
#    'kBGBW5_RPfMlYMzXxu1rkEFZt3Jq-bnVJ1sHCzxVerdUw_nKijITeIm1xDPOM1C7iF0ACBtWlMclRg']},
#  'info': {'gameCreation': 1665261933062,
#   'gameDuration': 1078,
#   'gameEndTimestamp': 1665263061755,
#   'gameId': 6099023320,
#   'gameMode': 'ARAM',
#   'gameName': 'teambuilder-match-6099023320',
#   'gameStartTimestamp': 1665261982859,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '12.19.471.6581',
#   'mapId': 12,
#   'participants': [{'assists': 28,
#     'baronKills': 0,
#     'basicPings': 3,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 1,
#      'abilityUses': 132,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 884.6542698155224,
#      'damageTakenOnTeamPercentage': 0.21826946252225957,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 2255.490234375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 23,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 4,
#      'gameLength': 1078.941158044476,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 626.5852843810803,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 9,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5.166666666666667,
#      'killAfterHiddenWithAlly': 5,
#      'killParticipation': 0.7560975609756098,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 10,
#      'laneMinionsFirst10Minutes': 11,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -23,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6653,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 25,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 14.702973308121727,
#      'skillshotsDodged': 20,
#      'skillshotsHit': 22,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 31,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 22,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.17138742752584102,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17055,
#     'champLevel': 17,
#     'championId': 25,
#     'championName': 'Morgana',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 400,
#     'damageDealtToObjectives': 400,
#     'damageDealtToTurrets': 400,
#     'damageSelfMitigated': 5430,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 11267,
#     'goldSpent': 7800,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 2,
#     'inhibitorsLost': 0,
#     'item0': 3020,
#     'item1': 6653,
#     'item2': 3070,
#     'item3': 3157,
#     'item4': 0,
#     'item5': 0,
#     'item6': 0,
#     'itemsPurchased': 11,
#     'killingSprees': 1,
#     'kills': 3,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 361,
#     'magicDamageDealt': 35854,
#     'magicDamageDealtToChampions': 14864,
#     'magicDamageTaken': 13957,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 958, 'var2': 18, 'var3': 0},
#         {'perk': 8139, 'var1': 877, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8210, 'var1': 34, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 726, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 2239,
#     'physicalDamageDealtToChampions': 585,
#     'physicalDamageTaken': 3123,
#     'profileIcon': 4804,
#     'puuid': 'I9zqZeIvTdKGdnmleOmmgbnohX5gfvaHYSb85EMxPZRqyVqaJgyHZ1mr5phJk6QP7JbdDpIhHkiqWw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 41,
#     'spell2Casts': 64,
#     'spell3Casts': 24,
#     'spell4Casts': 3,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 14,
#     'summonerId': 'V594CO_U8XDfTw23u5KvfoI1X-ehEaBIOZCEoBe6QOIOZk4',
#     'summonerLevel': 518,
#     'summonerName': 'Nαmı Bot',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 51,
#     'timePlayed': 1078,
#     'totalDamageDealt': 38551,
#     'totalDamageDealtToChampions': 15908,
#     'totalDamageShieldedOnTeammates': 2255,
#     'totalDamageTaken': 17561,
#     'totalHeal': 3303,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 22,
#     'totalTimeCCDealt': 114,
#     'totalTimeSpentDead': 146,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 458,
#     'trueDamageDealtToChampions': 458,
#     'trueDamageTaken': 481,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'assists': 20,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 102,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 898.645145887587,
#      'damageTakenOnTeamPercentage': 0.17518013561430062,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 4,
#      'gameLength': 1078.941158044476,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 646.9612724723546,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 4.333333333333333,
#      'killAfterHiddenWithAlly': 13,
#      'killParticipation': 0.6341463414634146,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 4,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 9,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -23,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6653,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 19,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 14.702973308121727,
#      'skillshotsDodged': 33,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 26,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 19,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.17409793302006532,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 16166,
#     'champLevel': 16,
#     'championId': 17,
#     'championName': 'Teemo',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 443,
#     'damageDealtToObjectives': 443,
#     'damageDealtToTurrets': 443,
#     'damageSelfMitigated': 3584,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 11633,
#     'goldSpent': 10400,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6653,
#     'item1': 4637,
#     'item2': 3020,
#     'item3': 1058,
#     'item4': 3108,
#     'item5': 3113,
#     'item6': 2052,
#     'itemsPurchased': 12,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 264,
#     'magicDamageDealt': 26152,
#     'magicDamageDealtToChampions': 14817,
#     'magicDamageTaken': 11158,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1125, 'var2': 21, 'var3': 0},
#         {'perk': 8126, 'var1': 941, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8009, 'var1': 2281, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 447, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 2483,
#     'physicalDamageDealtToChampions': 675,
#     'physicalDamageTaken': 2616,
#     'profileIcon': 1590,
#     'puuid': 'aYebJByywsg9lCWUE5Q9rwxjGX63bP9OOfTVzB6smKFMEMc0Fb7t9-WEc2GdnOSKZfOj8gZOaHGmbg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 50,
#     'spell2Casts': 5,
#     'spell3Casts': 0,
#     'spell4Casts': 47,
#     'summoner1Casts': 2,
#     'summoner1Id': 32,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'rh-WsgJrfzIJ6dNj0ALCTWw98Yjmr_BghaL8dFsNcsafsOex',
#     'summonerLevel': 168,
#     'summonerName': 'DerSascha x3',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 39,
#     'timePlayed': 1078,
#     'totalDamageDealt': 29303,
#     'totalDamageDealtToChampions': 16159,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 14094,
#     'totalHeal': 178,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 20,
#     'totalTimeCCDealt': 208,
#     'totalTimeSpentDead': 102,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 666,
#     'trueDamageDealtToChampions': 666,
#     'trueDamageTaken': 319,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'assists': 13,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 5,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 125,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 600,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 586.1380231765438,
#      'damageTakenOnTeamPercentage': 0.24830331621297844,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 34,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 4,
#      'gameLength': 1078.941158044476,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 682.7640604877022,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 10,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 4.75,
#      'killAfterHiddenWithAlly': 7,
#      'killParticipation': 0.4634146341463415,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 8,
#      'landSkillShotsEarlyGame': 13,
#      'laneMinionsFirst10Minutes': 5,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -23,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6691,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 16,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 15.437517724511167,
#      'skillshotsDodged': 50,
#      'skillshotsHit': 30,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 9,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 19,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 16,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.11355474267733758,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 16385,
#     'champLevel': 16,
#     'championId': 555,
#     'championName': 'Pyke',
#     'championTransform': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 15976,
#     'deaths': 4,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 12277,
#     'goldSpent': 11850,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3142,
#     'item1': 3111,
#     'item2': 6676,
#     'item3': 6691,
#     'item4': 3133,
#     'item5': 1036,
#     'item6': 0,
#     'itemsPurchased': 14,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 514,
#     'magicDamageDealt': 0,
#     'magicDamageDealtToChampions': 0,
#     'magicDamageTaken': 12819,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 9923, 'var1': 16, 'var2': 53, 'var3': 0},
#         {'perk': 8126, 'var1': 535, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 550, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9111, 'var1': 774, 'var2': 190, 'var3': 0},
#         {'perk': 9104, 'var1': 10, 'var2': 50, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 14344,
#     'physicalDamageDealtToChampions': 8319,
#     'physicalDamageTaken': 4358,
#     'profileIcon': 4162,
#     'puuid': 'jFsWEnsLlBlqnTL5nwrwSGYN16sfwtjP8uY2hAud5Ig9qFx-4ud61YrRF1BGzrBkTgYUuQdFoNLRtw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 59,
#     'spell2Casts': 34,
#     'spell3Casts': 21,
#     'spell4Casts': 11,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 14,
#     'summonerId': 'VqoHwWFuwJOd-dLA_UKOzSERUd5oc7TKwjP6JuRis6M36Ok',
#     'summonerLevel': 451,
#     'summonerName': 'Prôvidentia',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 30,
#     'timePlayed': 1078,
#     'totalDamageDealt': 16565,
#     'totalDamageDealtToChampions': 10540,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19978,
#     'totalHeal': 7291,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 6,
#     'totalTimeCCDealt': 131,
#     'totalTimeSpentDead': 88,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2220,
#     'trueDamageDealtToChampions': 2220,
#     'trueDamageTaken': 2799,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'assists': 11,
#     'baronKills': 0,
#     'basicPings': 1,
#     'bountyLevel': 5,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 83,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1025,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 2412.4263629608477,
#      'damageTakenOnTeamPercentage': 0.2028881486788283,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 5,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 4,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'fastestLegendary': 788.9179962425937,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 4,
#      'gameLength': 1078.941158044476,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 949.5579084515447,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 4,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 2,
#      'kda': 6.8,
#      'killAfterHiddenWithAlly': 20,
#      'killParticipation': 0.8292682926829268,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 4,
#      'killsNearEnemyTurret': 7,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 4,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 81,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 1,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 122,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -23,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 12,
#      'multikillsAfterAggressiveFlash': 2,
#      'mythicItemUsed': 6672,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 3,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 24,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 1,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 14.702973308121727,
#      'skillshotsDodged': 27,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 3,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 34,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 23,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.46736851055904527,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 16329,
#     'champLevel': 16,
#     'championId': 18,
#     'championName': 'Tristana',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 6958,
#     'damageDealtToObjectives': 6958,
#     'damageDealtToTurrets': 6958,
#     'damageSelfMitigated': 6505,
#     'deaths': 5,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 6,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 17075,
#     'goldSpent': 15500,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6672,
#     'item1': 3006,
#     'item2': 3046,
#     'item3': 3031,
#     'item4': 3072,
#     'item5': 3155,
#     'item6': 2052,
#     'itemsPurchased': 18,
#     'killingSprees': 4,
#     'kills': 23,
#     'lane': 'NONE',
#     'largestCriticalStrike': 804,
#     'largestKillingSpree': 9,
#     'largestMultiKill': 5,
#     'longestTimeSpentLiving': 450,
#     'magicDamageDealt': 16553,
#     'magicDamageDealtToChampions': 2292,
#     'magicDamageTaken': 11204,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 4,
#     'pentaKills': 1,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 159, 'var2': 45, 'var3': 0},
#         {'perk': 8009, 'var1': 1619, 'var2': 0, 'var3': 0},
#         {'perk': 9105, 'var1': 6, 'var2': 50, 'var3': 0},
#         {'perk': 8014, 'var1': 1431, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 5, 'var2': 3, 'var3': 0},
#         {'perk': 8410, 'var1': 53, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 118457,
#     'physicalDamageDealtToChampions': 37561,
#     'physicalDamageTaken': 3853,
#     'profileIcon': 5168,
#     'puuid': 'l9cVfu51JMHqDepa5v-FiNJNK6bI3aXhaTumk6w0JJ0d2MTbjWG7UKi-G8rN3Ar4DJIbZj3_z0FWrg',
#     'quadraKills': 2,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 30,
#     'spell2Casts': 20,
#     'spell3Casts': 26,
#     'spell4Casts': 7,
#     'summoner1Casts': 2,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 6,
#     'summonerId': 'CgjiCnPK3nCc9c4sEJGkWT7FCAkz2MpAgY4mlq9qGe66238',
#     'summonerLevel': 445,
#     'summonerName': 'Flurox',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 1,
#     'timePlayed': 1078,
#     'totalDamageDealt': 148368,
#     'totalDamageDealtToChampions': 43381,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 16324,
#     'totalHeal': 1036,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 152,
#     'totalTimeCCDealt': 9,
#     'totalTimeSpentDead': 138,
#     'totalUnitsHealed': 1,
#     'tripleKills': 3,
#     'trueDamageDealt': 13356,
#     'trueDamageDealtToChampions': 3526,
#     'trueDamageTaken': 1265,
#     'turretKills': 3,
#     'turretTakedowns': 4,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'assists': 29,
#     'baronKills': 0,
#     'basicPings': 2,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 2,
#      'abilityUses': 181,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 379.85828353322535,
#      'damageTakenOnTeamPercentage': 0.15535893697163308,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 5,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 15223.4365234375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 8,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 4,
#      'gameLength': 1078.941158044476,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 613.768465181168,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 4,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 6.4,
#      'killAfterHiddenWithAlly': 15,
#      'killParticipation': 0.7804878048780488,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 21,
#      'laneMinionsFirst10Minutes': 9,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -23,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6617,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 24,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 1,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 14.702973308121727,
#      'skillshotsDodged': 39,
#      'skillshotsHit': 43,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 32,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 21,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.07359138621771077,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15810,
#     'champLevel': 16,
#     'championId': 16,
#     'championName': 'Soraka',
#     'championTransform': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 361,
#     'damageDealtToObjectives': 361,
#     'damageDealtToTurrets': 361,
#     'damageSelfMitigated': 3538,
#     'deaths': 5,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 11037,
#     'goldSpent': 8100,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 2,
#     'inhibitorsLost': 0,
#     'item0': 6617,
#     'item1': 3070,
#     'item2': 3158,
#     'item3': 3083,
#     'item4': 3067,
#     'item5': 1028,
#     'item6': 2052,
#     'itemsPurchased': 13,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 290,
#     'magicDamageDealt': 8316,
#     'magicDamageDealtToChampions': 6529,
#     'magicDamageTaken': 11140,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 599, 'var2': 907, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 412, 'var3': 0},
#         {'perk': 8210, 'var1': 15, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 576, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8473, 'var1': 671, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 2543, 'var2': 386, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 4762,
#     'physicalDamageDealtToChampions': 301,
#     'physicalDamageTaken': 1068,
#     'profileIcon': 5538,
#     'puuid': '31o81vZvFSySno1vJzz3c1-VrAwUmzVN840r6-Vz2RfEkoLBJJTnMs5kvWP-72eVVtmvSsAqoUZEig',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 34,
#     'spell2Casts': 105,
#     'spell3Casts': 36,
#     'spell4Casts': 6,
#     'summoner1Casts': 4,
#     'summoner1Id': 13,
#     'summoner2Casts': 1,
#     'summoner2Id': 4,
#     'summonerId': 'qRjQ_jcMEjqL_KN_BsCGhdIRXZ1cwSjIDFoCVuWY46IvkVX9_j4rufPPhA',
#     'summonerLevel': 250,
#     'summonerName': 'Ignore me pIs',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 59,
#     'timePlayed': 1078,
#     'totalDamageDealt': 13078,
#     'totalDamageDealtToChampions': 6830,
#     'totalDamageShieldedOnTeammates': 1056,
#     'totalDamageTaken': 12500,
#     'totalHeal': 18067,
#     'totalHealsOnTeammates': 14166,
#     'totalMinionsKilled': 11,
#     'totalTimeCCDealt': 185,
#     'totalTimeSpentDead': 116,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 291,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'assists': 7,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 51,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 487.414497610927,
#      'damageTakenOnTeamPercentage': 0.19763948480449572,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 10,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 15,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 549.9609163600754,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 1078.941158044476,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 623.4691650728748,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 4,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.2,
#      'killAfterHiddenWithAlly': 7,
#      'killParticipation': 0.48,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 4,
#      'landSkillShotsEarlyGame': 4,
#      'laneMinionsFirst10Minutes': 17,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 19,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 0,
#      'moreEnemyJungleThanOpponent': -23,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6673,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 9,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 13,
#      'skillshotsHit': 25,
#      'snowballsHit': 6,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 12,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 11,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.12113044402069154,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 5,
#      'wardTakedownsBefore20M': 5,
#      'wardsGuarded': 0},
#     'champExperience': 13668,
#     'champLevel': 15,
#     'championId': 67,
#     'championName': 'Vayne',
#     'championTransform': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 421,
#     'damageDealtToObjectives': 421,
#     'damageDealtToTurrets': 421,
#     'damageSelfMitigated': 12431,
#     'deaths': 10,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 11211,
#     'goldSpent': 10300,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 3134,
#     'item1': 6673,
#     'item2': 3006,
#     'item3': 3153,
#     'item4': 3086,
#     'item5': 1036,
#     'item6': 0,
#     'itemsPurchased': 16,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'NONE',
#     'largestCriticalStrike': 419,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 229,
#     'magicDamageDealt': 64,
#     'magicDamageDealtToChampions': 64,
#     'magicDamageTaken': 7868,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 438, 'var2': 0, 'var3': 0},
#         {'perk': 8139, 'var1': 563, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 550, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9111, 'var1': 194, 'var2': 120, 'var3': 0},
#         {'perk': 8014, 'var1': 323, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 28777,
#     'physicalDamageDealtToChampions': 7476,
#     'physicalDamageTaken': 10278,
#     'profileIcon': 547,
#     'puuid': 'QEbFAox6b90ARcUXKddMIBKZFw3OQTEGKuvapgRjrF9jytBmLHGVp5AnDLovKUrFDbFwtD-ZCg1brA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 31,
#     'spell2Casts': 0,
#     'spell3Casts': 14,
#     'spell4Casts': 6,
#     'summoner1Casts': 18,
#     'summoner1Id': 32,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'd3Y_qDS2_y5Fak5AtnvhNzail1Gqv1JPsSG0Sosl-D6Wtyk',
#     'summonerLevel': 182,
#     'summonerName': 'sasukaru',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 6,
#     'timePlayed': 1078,
#     'totalDamageDealt': 35685,
#     'totalDamageDealtToChampions': 8764,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19513,
#     'totalHeal': 1341,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 38,
#     'totalTimeCCDealt': 37,
#     'totalTimeSpentDead': 210,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 6843,
#     'trueDamageDealtToChampions': 1224,
#     'trueDamageTaken': 1366,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'assists': 8,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 56,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 225.91198369562974,
#      'damageTakenOnTeamPercentage': 0.2522684224591108,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 16,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 549.9609163600754,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 1078.941158044476,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 514.8756112780994,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 6,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 0.8888888888888888,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.32,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 4,
#      'laneMinionsFirst10Minutes': 9,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 3,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 0,
#      'moreEnemyJungleThanOpponent': -23,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6662,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 7,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 23,
#      'skillshotsHit': 10,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
# ...
#     'timeCCingOthers': 22,
#     'timePlayed': 1078,
#     'totalDamageDealt': 14105,
#     'totalDamageDealtToChampions': 4796,
#     'totalDamageShieldedOnTeammates': 4335,
#     'totalDamageTaken': 16608,
#     'totalHeal': 1042,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 14,
#     'totalTimeCCDealt': 193,
#     'totalTimeSpentDead': 150,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 114,
#     'trueDamageDealtToChampions': 35,
#     'trueDamageTaken': 1306,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'assists': 13,
#     'baronKills': 0,
#     'basicPings': 18,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 204,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1082.6263039609146,
#      'damageTakenOnTeamPercentage': 0.17090350225385817,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 2430.2822265625,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 28,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 549.9609163600754,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 1078.941158044476,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 609.9836672908444,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 7,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 2.142857142857143,
#      'killAfterHiddenWithAlly': 7,
#      'killParticipation': 0.6,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 7,
#      'landSkillShotsEarlyGame': 14,
#      'laneMinionsFirst10Minutes': 26,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 31,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 0,
#      'moreEnemyJungleThanOpponent': -23,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6655,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 13,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 10,
#      'skillshotsHit': 49,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 15,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 14,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.26905027558689065,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 3,
#      'wardTakedownsBefore20M': 3,
#      'wardsGuarded': 0},
#     'champExperience': 13673,
#     'champLevel': 15,
#     'championId': 61,
#     'championName': 'Orianna',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 970,
#     'damageDealtToObjectives': 970,
#     'damageDealtToTurrets': 970,
#     'damageSelfMitigated': 10278,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 10968,
#     'goldSpent': 10135,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 6655,
#     'item1': 3020,
#     'item2': 2420,
#     'item3': 3089,
#     'item4': 3108,
#     'item5': 1052,
#     'item6': 0,
#     'itemsPurchased': 14,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 289,
#     'magicDamageDealt': 53107,
#     'magicDamageDealtToChampions': 18965,
#     'magicDamageTaken': 7138,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 805, 'var2': 0, 'var3': 0},
#         {'perk': 8139, 'var1': 838, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 550, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8275, 'var1': 10, 'var2': 0, 'var3': 0},
#         {'perk': 8234, 'var1': 4559, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 3278,
#     'physicalDamageDealtToChampions': 502,
#     'physicalDamageTaken': 8543,
#     'profileIcon': 4413,
#     'puuid': '_fg-80eVskvALqfFDEgwI95q_HkF_Yvkxykmf9BNMAZrFv4hYhXnxrQDTgRDR-yz_ZnBK0Tl8wvOSw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 86,
#     'spell2Casts': 49,
#     'spell3Casts': 63,
#     'spell4Casts': 6,
#     'summoner1Casts': 6,
#     'summoner1Id': 7,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': '1PV0DFqu8I3SSfVcLki5Jv6F30LnAgIv3g1p9JzIFlmSb8I',
#     'summonerLevel': 557,
#     'summonerName': 'PROJECT Lemberg',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 26,
#     'timePlayed': 1078,
#     'totalDamageDealt': 56602,
#     'totalDamageDealtToChampions': 19468,
#     'totalDamageShieldedOnTeammates': 1944,
#     'totalDamageTaken': 16873,
#     'totalHeal': 3619,
#     'totalHealsOnTeammates': 486,
#     'totalMinionsKilled': 52,
#     'totalTimeCCDealt': 289,
#     'totalTimeSpentDead': 150,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 217,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 1192,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'assists': 6,
#     'baronKills': 0,
#     'basicPings': 1,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 218,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1700,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1961.203380831426,
#      'damageTakenOnTeamPercentage': 0.21097203715613388,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 51,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 549.9609163600754,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 1078.941158044476,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 839.1880363149761,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3,
#      'killAfterHiddenWithAlly': 11,
#      'killParticipation': 0.96,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 3,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 1,
#      'killsUnderOwnTurret': 10,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 40,
#      'laneMinionsFirst10Minutes': 31,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 52,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -23,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 5,
#      'multikillsAfterAggressiveFlash': 1,
#      'mythicItemUsed': 6655,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 9,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 19,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 17,
#      'skillshotsHit': 103,
#      'snowballsHit': 6,
#      'soloBaronKills': 0,
#      'soloKills': 2,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 24,
#      'takedownsAfterGainingLevelAdvantage': 2,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 22,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.48739099370126393,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 16883,
#     'champLevel': 17,
#     'championId': 711,
#     'championName': 'Vex',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 105,
#     'damageDealtToObjectives': 105,
#     'damageDealtToTurrets': 105,
#     'damageSelfMitigated': 19804,
#     'deaths': 8,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 5,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 15090,
#     'goldSpent': 14000,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 6655,
#     'item1': 3157,
#     'item2': 4645,
#     'item3': 3089,
#     'item4': 3020,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 13,
#     'killingSprees': 4,
#     'kills': 18,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 408,
#     'magicDamageDealt': 100245,
#     'magicDamageDealtToChampions': 33686,
#     'magicDamageTaken': 8154,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1800, 'var2': 23, 'var3': 0},
#         {'perk': 8143, 'var1': 839, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8237, 'var1': 753, 'var2': 0, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 806, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 3885,
#     'physicalDamageDealtToChampions': 830,
#     'physicalDamageTaken': 11300,
#     'profileIcon': 546,
#     'puuid': 'kBGBW5_RPfMlYMzXxu1rkEFZt3Jq-bnVJ1sHCzxVerdUw_nKijITeIm1xDPOM1C7iF0ACBtWlMclRg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 136,
#     'spell2Casts': 22,
#     'spell3Casts': 43,
#     'spell4Casts': 17,
#     'summoner1Casts': 1,
#     'summoner1Id': 4,
#     'summoner2Casts': 13,
#     'summoner2Id': 32,
#     'summonerId': 'd7Wj5TXvcdkxAsX0GlWL1-_9sH-izvb7wjpDs14Vsw0tIKE',
#     'summonerLevel': 419,
#     'summonerName': 'Ackérmann',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 41,
#     'timePlayed': 1078,
#     'totalDamageDealt': 104917,
#     'totalDamageDealtToChampions': 35267,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 20830,
#     'totalHeal': 1290,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 71,
#     'totalTimeCCDealt': 391,
#     'totalTimeSpentDead': 202,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 786,
#     'trueDamageDealtToChampions': 749,
#     'trueDamageTaken': 1374,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False}],
#   'platformId': 'EUW1',
#   'queueId': 450,
#   'teams': [{'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 41},
#      'dragon': {'first': False, 'kills': 0},
#      'inhibitor': {'first': True, 'kills': 2},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 4}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 26},
#      'dragon': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 1}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %%
D={}
for game in res_games:
    api_url = f"https://europe.api.riotgames.com/lol/match/v5/matches/{game}?api_key={RIOT_API_KEY}"
    response = requests.get(api_url)
    match = response.json()
    D[game]=match["info"]

# %%
df2=pd.DataFrame(D).transpose()
df2
# Out:
#                   gameCreation gameDuration gameEndTimestamp      gameId  \
# EUW1_6099023320  1665261933062         1078    1665263061755  6099023320
# EUW1_6098938001  1665260108687         1426    1665261635970  6098938001
# EUW1_6098923859  1665258653516         1177    1665259931765  6098923859
# EUW1_6095728706  1665088874422          878    1665089843433  6095728706
# EUW1_6095586878  1665081709012         1400    1665083236896  6095586878
# EUW1_6095573397  1665080406364         1023    1665081511801  6095573397
# EUW1_6094521483  1665004298597         1322    1665005638816  6094521483
# EUW1_6093028177  1664916931684         1305    1664918279477  6093028177
# EUW1_6086735640  1664559580809         1222    1664560853171  6086735640
# EUW1_6086743125  1664558455363          916    1664559476068  6086743125
#
#                 gameMode                      gameName gameStartTimestamp  \
# EUW1_6099023320     ARAM  teambuilder-match-6099023320      1665261982859
# EUW1_6098938001     ARAM  teambuilder-match-6098938001      1665260209641
# EUW1_6098923859     ARAM  teambuilder-match-6098923859      1665258754231
# EUW1_6095728706     ARAM  teambuilder-match-6095728706      1665088965137
# EUW1_6095586878     ARAM  teambuilder-match-6095586878      1665081836214
# EUW1_6095573397     ARAM  teambuilder-match-6095573397      1665080488558
# EUW1_6094521483     ARAM  teambuilder-match-6094521483      1665004315905
# EUW1_6093028177     ARAM  teambuilder-match-6093028177      1664916973562
# EUW1_6086735640     ARAM  teambuilder-match-6086735640      1664559631170
# EUW1_6086743125     ARAM  teambuilder-match-6086743125      1664558559067
#
#                      gameType     gameVersion mapId  \
# EUW1_6099023320  MATCHED_GAME  12.19.471.6581    12
# EUW1_6098938001  MATCHED_GAME  12.19.471.6581    12
# EUW1_6098923859  MATCHED_GAME  12.19.471.6581    12
# EUW1_6095728706  MATCHED_GAME  12.19.471.6581    12
# EUW1_6095586878  MATCHED_GAME  12.19.471.6581    12
# EUW1_6095573397  MATCHED_GAME  12.19.471.6581    12
# EUW1_6094521483  MATCHED_GAME  12.19.471.6581    12
# EUW1_6093028177  MATCHED_GAME  12.18.468.3251    12
# EUW1_6086735640  MATCHED_GAME  12.18.468.3251    12
# EUW1_6086743125  MATCHED_GAME  12.18.468.3251    12
#
#                                                       participants platformId  \
# EUW1_6099023320  [{'assists': 28, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6098938001  [{'assists': 10, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6098923859  [{'assists': 13, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6095728706  [{'assists': 24, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6095586878  [{'assists': 36, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6095573397  [{'assists': 41, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6094521483  [{'assists': 25, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6093028177  [{'assists': 38, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6086735640  [{'assists': 29, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6086743125  [{'assists': 28, 'baronKills': 0, 'basicPings'...       EUW1
#
#                 queueId                                              teams  \
# EUW1_6099023320     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6098938001     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6098923859     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6095728706     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6095586878     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6095573397     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6094521483     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6093028177     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6086735640     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6086743125     450  [{'bans': [], 'objectives': {'baron': {'first'...
#
#                 tournamentCode
# EUW1_6099023320
# EUW1_6098938001
# EUW1_6098923859
# EUW1_6095728706
# EUW1_6095586878
# EUW1_6095573397
# EUW1_6094521483
# EUW1_6093028177
# EUW1_6086735640
# EUW1_6086743125

# %% [markdown]
# # 3. Pagination and quota management

# %% [markdown]
# # 3.1 get all registered matches of the player into a similar dataframe

# %% [markdown]
# First get all match ids

# %%
end = True
count = 0
total_games = []
while end:
    recup_games = f"https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start={count}&count={nb_games}&api_key={RIOT_API_KEY}"
    reponse_games = requests.get(recup_games)
    res_games = reponse_games.json()
    total_games += res_games
    count +=100
    end = (len(res_games)==100)

# %%
len(total_games)
# Out:
# 336

# %%
import time

D={}
for game in total_games:
    api_url = f"https://europe.api.riotgames.com/lol/match/v5/matches/{game}?api_key={RIOT_API_KEY}"
    response = requests.get(api_url)
    while response.status_code==429:
        time.sleep(2)
        api_url = f"https://europe.api.riotgames.com/lol/match/v5/matches/{game}?api_key={RIOT_API_KEY}"
        response = requests.get(api_url)
        print("Waiting for request ...")
    match = response.json()
    D[game]=match["info"]
    print(response)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# Waiting for request ...
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
df3 = pd.DataFrame(D).transpose()
df3
# Out:
#                   gameCreation gameDuration gameEndTimestamp      gameId  \
# EUW1_6099023320  1665261933062         1078    1665263061755  6099023320
# EUW1_6098938001  1665260108687         1426    1665261635970  6098938001
# EUW1_6098923859  1665258653516         1177    1665259931765  6098923859
# EUW1_6095728706  1665088874422          878    1665089843433  6095728706
# EUW1_6095586878  1665081709012         1400    1665083236896  6095586878
# ...                        ...          ...              ...         ...
# EUW1_4981459278  1608067628000      1826487              NaN  4981459278
# EUW1_4981385498  1608065825000      1305395              NaN  4981385498
# EUW1_4981349989  1608064600000       991934              NaN  4981349989
# EUW1_4981276819  1608062993000       940189              NaN  4981276819
# EUW1_4976517336  1607807539000      1121411              NaN  4976517336
#
#                 gameMode                      gameName gameStartTimestamp  \
# EUW1_6099023320     ARAM  teambuilder-match-6099023320      1665261982859
# EUW1_6098938001     ARAM  teambuilder-match-6098938001      1665260209641
# EUW1_6098923859     ARAM  teambuilder-match-6098923859      1665258754231
# EUW1_6095728706     ARAM  teambuilder-match-6095728706      1665088965137
# EUW1_6095586878     ARAM  teambuilder-match-6095586878      1665081836214
# ...                  ...                           ...                ...
# EUW1_4981459278     ARAM  teambuilder-match-4981459278      1608067751393
# EUW1_4981385498     ARAM  teambuilder-match-4981385498      1608065923981
# EUW1_4981349989     ARAM  teambuilder-match-4981349989      1608064635203
# EUW1_4981276819     ARAM  teambuilder-match-4981276819      1608063087101
# EUW1_4976517336     ARAM  teambuilder-match-4976517336      1607807616001
#
#                      gameType     gameVersion mapId  \
# EUW1_6099023320  MATCHED_GAME  12.19.471.6581    12
# EUW1_6098938001  MATCHED_GAME  12.19.471.6581    12
# EUW1_6098923859  MATCHED_GAME  12.19.471.6581    12
# EUW1_6095728706  MATCHED_GAME  12.19.471.6581    12
# EUW1_6095586878  MATCHED_GAME  12.19.471.6581    12
# ...                       ...             ...   ...
# EUW1_4981459278  MATCHED_GAME  10.25.348.1797    12
# EUW1_4981385498  MATCHED_GAME  10.25.348.1797    12
# EUW1_4981349989  MATCHED_GAME  10.25.348.1797    12
# EUW1_4981276819  MATCHED_GAME  10.25.348.1797    12
# EUW1_4976517336  MATCHED_GAME  10.25.348.1797    12
#
#                                                       participants platformId  \
# EUW1_6099023320  [{'assists': 28, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6098938001  [{'assists': 10, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6098923859  [{'assists': 13, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6095728706  [{'assists': 24, 'baronKills': 0, 'basicPings'...       EUW1
# EUW1_6095586878  [{'assists': 36, 'baronKills': 0, 'basicPings'...       EUW1
# ...                                                            ...        ...
# EUW1_4981459278  [{'assists': 29, 'baronKills': 0, 'bountyLevel...       EUW1
# EUW1_4981385498  [{'assists': 23, 'baronKills': 0, 'bountyLevel...       EUW1
# EUW1_4981349989  [{'assists': 15, 'baronKills': 0, 'bountyLevel...       EUW1
# EUW1_4981276819  [{'assists': 16, 'baronKills': 0, 'bountyLevel...       EUW1
# EUW1_4976517336  [{'assists': 25, 'baronKills': 0, 'bountyLevel...       EUW1
#
#                 queueId                                              teams  \
# EUW1_6099023320     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6098938001     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6098923859     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6095728706     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_6095586878     450  [{'bans': [], 'objectives': {'baron': {'first'...
# ...                 ...                                                ...
# EUW1_4981459278     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_4981385498     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_4981349989     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_4981276819     450  [{'bans': [], 'objectives': {'baron': {'first'...
# EUW1_4976517336     450  [{'bans': [], 'objectives': {'baron': {'first'...
#
#                 tournamentCode
# EUW1_6099023320
# EUW1_6098938001
# EUW1_6098923859
# EUW1_6095728706
# EUW1_6095586878
# ...                        ...
# EUW1_4981459278            NaN
# EUW1_4981385498            NaN
# EUW1_4981349989            NaN
# EUW1_4981276819            NaN
# EUW1_4976517336            NaN
#
# [336 rows x 15 columns]

# %% [markdown]
# You will need to paginate using proper parameter to get all matches infos. You may go over your quota, check response status code and act properly to get all data. Will take several minutes to execute (more than 6 minute for me), print advancement to speed up debugging.
