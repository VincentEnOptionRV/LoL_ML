# %% [markdown]
# ## ML tentative 1

# %%
import pandas as pd

# %%
data = pd.read_pickle("infos_games.pickle")

# %%
data
# Out:
#              GameId  GameDuration gameMode  win  \
# 0   EUW1_6111736235          1024      URF    2
# 1   EUW1_6111632386          1153      URF    2
# 2   EUW1_6110745821           883      URF    1
# 3   EUW1_6110639675          1325      URF    2
# 4   EUW1_6110065467          1113      URF    1
# ..              ...           ...      ...  ...
# 95  EUW1_6030308673          2173  CLASSIC    2
# 96  EUW1_6030124988          2344  CLASSIC    2
# 97  EUW1_6029974109          1865  CLASSIC    2
# 98  EUW1_6029836748          1212  CLASSIC    1
# 99  EUW1_6029767351          2114  CLASSIC    2
#
#                                 championName1  \
# 0     [Syndra, KogMaw, Sylas, Pyke, MasterYi]
# 1         [Garen, Nunu, Kassadin, Lux, Akali]
# 2      [Velkoz, Hecarim, Trundle, Talon, Zed]
# 3      [Ezreal, Nunu, Morgana, Veigar, Kaisa]
# 4     [Yone, Ashe, Ziggs, Jinx, Heimerdinger]
# ..                                        ...
# 95        [Gwen, MasterYi, Yone, Nilah, Pyke]
# ...

# %%
data2 = data[["championId1"]].head()
data2
# Out:
#                championId1
# 0  [134, 96, 517, 555, 11]
# 1     [86, 20, 38, 99, 84]
# 2  [161, 120, 48, 91, 238]
# 3    [81, 20, 25, 45, 145]
# 4  [777, 22, 115, 222, 74]

# %%
print(type(data2.championId1[0]))
# Out:
# <class 'list'>

# %%
data_f= pd.DataFrame(data2.championId1.to_list(), columns=['1', '2','3','4','5'])
print(data_f)
# Out:
#      1    2    3    4    5
# 0  134   96  517  555   11
# 1   86   20   38   99   84
# 2  161  120   48   91  238
# 3   81   20   25   45  145
# 4  777   22  115  222   74
