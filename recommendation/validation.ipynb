# %%
import pickle
import os
import numpy as np
import matplotlib.pyplot as plt
A = pickle.load(open(f"validation.pkl", 'rb'))
vals=[np.arange(0,600,25),np.arange(0,800,25),np.arange(0.45,0.55,0.01),[True,False],[True,False],np.arange(1400,1900,50),np.arange(-10,10,2),np.arange(0,100000,5000),np.arange(0,50,2),np.arange(0,50,2),np.arange(0.45,0.55,0.01),np.arange(0,100,5)]
V = ["LVL","TOTAL","GWR","HOT","FILL","RANK","VS","MAS","WCH","LCH","WRCH","TOTCH"]
for i in range(12):
    plt.plot(vals[i],list(map(lambda x:np.sum(np.array(x)>np.mean(x)),A[i])))
    plt.title(f"Variation du score en fonction de {V[i]}")
    plt.show()
